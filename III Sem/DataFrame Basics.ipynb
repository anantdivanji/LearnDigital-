# %% [markdown]
# # what is DataFrame?
# - - Dataframe is a 2Dimensional labelled data structure with row nad columns where columns are of different data types.
#   - You can thiink of it like a Excel sheet or a SQL Table having many rows and many columns

# %% [markdown]
# # Creating a DataFrame:

# %%
 
import pandas as pd
 
# intialise data of lists.
data = {'Name':['Tom', 'nick', 'krish', 'jack'],
        'Age':[20, 21, 19, 18]}
 
# Create DataFrame
df = pd.DataFrame(data)
 
# Print the output.
print(df)
# Out:
#     Name  Age
# 0    Tom   20
# 1   nick   21
# 2  krish   19
# 3   jack   18

# %%
data={"name":["Bill","Tom","Tim","John","Alex","Vanessa","Kate"],      
      "score":[90,80,85,75,95,60,65],      
      "sport":["Wrestling","Football","Skiing","Swimming","Tennis",
               "Karete","Surfing"],      
      "gender":["M","M","M","M","F","F","F"]}

df2 = pd.DataFrame(data)
df2
# Out:
#       name  score      sport gender
# 0     Bill     90  Wrestling      M
# 1      Tom     80   Football      M
# 2      Tim     85     Skiing      M
# 3     John     75   Swimming      M
# 4     Alex     95     Tennis      F
# 5  Vanessa     60     Karete      F
# 6     Kate     65    Surfing      F

# %% [markdown]
# #### Head() will display the top rows by the number specified in the function. By default head will display the
# #### top 5 rows of the data

# %%
df2.head(3)
# Out:
#    name  score      sport gender
# 0  Bill     90  Wrestling      M
# 1   Tom     80   Football      M
# 2   Tim     85     Skiing      M

# %%
df2.head()
# Out:
#    name  score      sport gender
# 0  Bill     90  Wrestling      M
# 1   Tom     80   Football      M
# 2   Tim     85     Skiing      M
# 3  John     75   Swimming      M
# 4  Alex     95     Tennis      F

# %%
df2.tail(2)
# Out:
#       name  score    sport gender
# 5  Vanessa     60   Karete      F
# 6     Kate     65  Surfing      F

# %%
df2.tail()
# Out:
#       name  score     sport gender
# 2      Tim     85    Skiing      M
# 3     John     75  Swimming      M
# 4     Alex     95    Tennis      F
# 5  Vanessa     60    Karete      F
# 6     Kate     65   Surfing      F

# %%
df2.shape    # displays the number of rows and columns present in the data
# Out:
# (7, 4)

# %%
df2.ndim      # display the dimension of the dataframe. here 2 as df2 is the dataframe
# Out:
# 2

# %%
type(df2)
# Out:
# pandas.core.frame.DataFrame

# %%
df2.dtypes
# Out:
# name      object
# score      int64
# sport     object
# gender    object
# dtype: object

# %%
data={"name":["Bill","Tom","Tim","John","Alex","Vanessa","Kate"],      
      "score":[90,80,85,75,95,60,65],      
      "sport":["Wrestling","Football","Skiing","Swimming","Tennis",
               "Karete","Surfing"],      
      "gender":["M","M","M","M","F","F","F"]}

df3 = pd.DataFrame(data, columns = ["name", "gender", "sport", "score"])
df3
# Out:
#       name gender      sport  score
# 0     Bill      M  Wrestling     90
# 1      Tom      M   Football     80
# 2      Tim      M     Skiing     85
# 3     John      M   Swimming     75
# 4     Alex      F     Tennis     95
# 5  Vanessa      F     Karete     60
# 6     Kate      F    Surfing     65

# %%
df2
# Out:
#       name  score      sport gender
# 0     Bill     90  Wrestling      M
# 1      Tom     80   Football      M
# 2      Tim     85     Skiing      M
# 3     John     75   Swimming      M
# 4     Alex     95     Tennis      F
# 5  Vanessa     60     Karete      F
# 6     Kate     65    Surfing      F

# %%
df=pd.DataFrame(data,columns=["name", "sport", "gender", "score", "age"],
                index=["one","two","three","four","five","six","seven"])
df
# Out:
#           name      sport gender  score  age
# one       Bill  Wrestling      M     90  NaN
# two        Tom   Football      M     80  NaN
# three      Tim     Skiing      M     85  NaN
# four      John   Swimming      M     75  NaN
# five      Alex     Tennis      F     95  NaN
# six    Vanessa     Karete      F     60  NaN
# seven     Kate    Surfing      F     65  NaN

# %%
df["sport"]
# Out:
# one      Wrestling
# two       Football
# three       Skiing
# four      Swimming
# five        Tennis
# six         Karete
# seven      Surfing
# Name: sport, dtype: object

# %% [markdown]
# # observations:
# - When a single column is selected and displayed in the output we get a series output, indicating that every single
# column of a DataFrame is a series.
# - From this example we can say that, a DataFrame is a collection of multiple series combined together.

# %%
## Selecting multiple columns from the dataframe
df[["gender", "sport"]]
# Out:
#       gender      sport
# one        M  Wrestling
# two        M   Football
# three      M     Skiing
# four       M   Swimming
# five       F     Tennis
# six        F     Karete
# seven      F    Surfing

# %% [markdown]
# # Observation:
# - When you want to select and display more than 1 column then the column names must be specified in a list

# %%
# another way of selecting and displaying a column
df.sport
# Out:
# one      Wrestling
# two       Football
# three       Skiing
# four      Swimming
# five        Tennis
# six         Karete
# seven      Surfing
# Name: sport, dtype: object

# %% [markdown]
# ## Note: Using the above dot method we cannot select multiple columns from the data hence the bracket method is preferred

# %%
df["sport"]
# Out:
# one      Wrestling
# two       Football
# three       Skiing
# four      Swimming
# five        Tennis
# six         Karete
# seven      Surfing
# Name: sport, dtype: object

# %%
df[["sport"]]
# Out:
#            sport
# one    Wrestling
# two     Football
# three     Skiing
# four    Swimming
# five      Tennis
# six       Karete
# seven    Surfing

# %% [markdown]
# # Note:
# - When you are selecting and displaying one column from the dataframe using data[] will give series output
# - Using data[[]] will give a dataframe output

# %%
# Selecitng and displaying one row of the data
df.loc["one"]
# Out:
# name           Bill
# sport     Wrestling
# gender            M
# score            90
# age             NaN
# Name: one, dtype: object

# %%
df.loc[["one", "two"]]
# Out:
#      name      sport gender  score  age
# one  Bill  Wrestling      M     90  NaN
# two   Tom   Football      M     80  NaN

# %%
df
# Out:
#           name      sport gender  score  age
# one       Bill  Wrestling      M     90  NaN
# two        Tom   Football      M     80  NaN
# three      Tim     Skiing      M     85  NaN
# four      John   Swimming      M     75  NaN
# five      Alex     Tennis      F     95  NaN
# six    Vanessa     Karete      F     60  NaN
# seven     Kate    Surfing      F     65  NaN

# %%
# Setting a value to a column
df["age"] = 18
df
# Out:
#           name      sport gender  score  age
# one       Bill  Wrestling      M     90   18
# two        Tom   Football      M     80   18
# three      Tim     Skiing      M     85   18
# four      John   Swimming      M     75   18
# five      Alex     Tennis      F     95   18
# six    Vanessa     Karete      F     60   18
# seven     Kate    Surfing      F     65   18

# %%
# to set different values to age colum

df=pd.DataFrame(data,columns=["name", "sport", "gender", "score", "age"], 
                index=["one","two","three","four","five","six","seven"])
values=[18,19,20,18,17,17,18]
df["age"]=values
df
# Out:
#           name      sport gender  score  age
# one       Bill  Wrestling      M     90   18
# two        Tom   Football      M     80   19
# three      Tim     Skiing      M     85   20
# four      John   Swimming      M     75   18
# five      Alex     Tennis      F     95   17
# six    Vanessa     Karete      F     60   17
# seven     Kate    Surfing      F     65   18

# %% [markdown]
# # OBSERVATION:
# - To set a same value to the entire column then df["col_name"] = value
# - To set a different set fof values to the entire column then define the values in a "list" and then
#  df["col_name"] = the list.

# %%
df
# Out:
#           name      sport gender  score  age
# one       Bill  Wrestling      M     90   18
# two        Tom   Football      M     80   19
# three      Tim     Skiing      M     85   20
# four      John   Swimming      M     75   18
# five      Alex     Tennis      F     95   17
# six    Vanessa     Karete      F     60   17
# seven     Kate    Surfing      F     65   18

# %%
# Creatinga new column in the data with existing columns 
df["pass"] = df["score"] >= 70

# %%
df
# Out:
#           name      sport gender  score  age   pass
# one       Bill  Wrestling      M     90   18   True
# two        Tom   Football      M     80   19   True
# three      Tim     Skiing      M     85   20   True
# four      John   Swimming      M     75   18   True
# five      Alex     Tennis      F     95   17   True
# six    Vanessa     Karete      F     60   17  False
# seven     Kate    Surfing      F     65   18  False

# %%
# del a column from the data
del df["pass"]
df
# Out:
#           name      sport gender  score  age
# one       Bill  Wrestling      M     90   18
# two        Tom   Football      M     80   19
# three      Tim     Skiing      M     85   20
# four      John   Swimming      M     75   18
# five      Alex     Tennis      F     95   17
# six    Vanessa     Karete      F     60   17
# seven     Kate    Surfing      F     65   18

# %%
df.T
# Out:
#               one       two   three      four    five      six    seven
# name         Bill       Tom     Tim      John    Alex  Vanessa     Kate
# sport   Wrestling  Football  Skiing  Swimming  Tennis   Karete  Surfing
# gender          M         M       M         M       F        F        F
# score          90        80      85        75      95       60       65
# age            18        19      20        18      17       17       18
